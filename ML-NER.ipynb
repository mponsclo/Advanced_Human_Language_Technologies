# %% [markdown]
# # Machine Learning NER

# %%
from os import listdir
from xml.dom.minidom import parse
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag
from evaluator import *

# %%
import nltk
stopwords = set(stopwords.words("english"))
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### Tokenize Text

# %%
def tokenize(s):

    token_list = []
    tokens = word_tokenize(s)
    
    for t in tokens:
            offsetFrom = s.find(t)
            offsetTo = offsetFrom + len(t) - 1
            token_list.append((t, offsetFrom, offsetTo))
            
    return token_list

# %% [markdown]
# ### Extract features

# %%
sent_1 = 'Ascorbic acid, aspirin, and the common cold PCP'
sent_2 = 'Phenothiazines and butyrophenones may reduce or reverse the depressor effect of epinephrine'

def has_numbers(word):
    return any(l.isdigit() for l in word)
def num_digits(word):
    return sum(l.isdigit() for l in word)

# %%
SIMPLE_DB_PATH = './resources/HSDB.txt'
DRUG_BANK_PATH = './resources/DrugBank.txt'

SimpleDrugDb = set()
DrugBank = {'drug' : set(), 'brand': set(), 'group': set()}

def read_drug_list_files():
    '''
    Read the drug databases.
    '''
    resource_file = open(SIMPLE_DB_PATH, 'r')
    lines = resource_file.readlines()
    global SimpleDrugDb
    SimpleDrugDb = set([d[:-1].lower() for d in lines])

    resource_file = open(DRUG_BANK_PATH, 'r')
    lines = resource_file.readlines()
    global DrugBank
    split_lines = [(line.split('|')[0].lower(), line.split('|')[1][:-1]) for line in lines]

    for name, n_type in split_lines:
        DrugBank[n_type].add(name)

# %%
def use_db_resources(word):
    
    drug_n = ["PCP", "18-MC", "ibogaine", "MHD", "endotoxin", "toxin", "NANM", "ginsenosides", 
             "NaCMC", "PTX", "coumaphos", "contortrostatin", "resveratrol", "GSLS", "methylglyoxal",
             "hydrodolasetron", "neurotensin"]

    if (word.lower() in SimpleDrugDb):
        return True, "drug"
    elif (word.lower() in DrugBank["drug"]):
        return True, "drug"
    elif (word.lower() in DrugBank["brand"]):
        return True, "brand"
    elif (word.lower() in DrugBank["group"]):
        return True, "group"
    elif (True in [word in word for word in drug_n]):
        return True, "drug_n"
    else:
        return False, ""

# %% [markdown]
# ### Get tag

# %%
def get_tag(token, gold):
    '''
    Input:
        token: A token, i.e. one triple (word, offsetFrom, offsetTo)
        gold: A list of ground truth entities, i.e. a list of triples (offsetFrom, offsetTo, type)
        
    Output:
        The B-I-O ground truth tag for the given token ("B-drug", "I-drug", "B-group", "I-group", "O", ...)
    '''
    (form, start, end) = token
    for (offsetFrom, offsetTo, Type) in gold:
        if start == offsetFrom and end<=offsetTo:
            return "B-"+Type # First letter of token equals 0 -> Beginning
        elif start > offsetFrom and end <=offsetTo:
            return "I-"+Type # Word not in the beginning
    return "O"

# %%
print(get_tag ((" Ascorbic " ,0 ,7) , [(0 , 12, " drug ") , (15 , 21, " brand ") ]))
print(get_tag ((" acid " ,9 ,12) , [(0 , 12, " drug ") , (15 , 21, " brand ") ]))
print(get_tag ((" common " ,32 ,37) , [(0 , 12, " drug ") , (15 , 21, " brand ") ]) )
print(get_tag ((" aspirin " ,15 ,21) , [(0 , 12, " drug ") , (15 , 21, " brand ") ]))
# Out:
# B- drug
# I- drug
# O
# B- brand

# %%
def extract_features(tokenized_sentence, should_look_up=False):
    '''
    Input:
        s: A tokenized sentence (list of triples (word, offsetFrom, offsetTo) )
        
    Output: 
        A list of feature vectors, one per token.
        Features are binary and vectors are in sparse representeation (i.e. only active features are listed)
    '''
    
    features = []
    
    for i in range(0, len(tokenized_sentence)):
        t = tokenized_sentence[i][0]
        punct = [".",",",";",":","?","!"]
        
        # length, number of digits, rules 
        
        tokenFeatures =  [
            "form=" + t,
            "formlower=" + t.lower(),
            "suf3=" + t[-3:],
            "suf4=" + t[-4:],
            "suf5=" + t[-5:],
            "prfx3=" + t[:3],
            "prfx4=" + t[:4],
            "prfx5=" + t[:5], 
            "capitalized=%s " % t.istitle(),
            "uppercase=%s" % t.isupper(),
            "digit=%s" % t.isdigit(),
            "stopword=%s" % (t in stopwords),
            "punctuation=%s" % (t in punct),
            "length=%s" % len(t),
            "posTag=%s" % pos_tag(t)[0][1], # ?
            "lemma=%s" % wordnet_lemmatizer.lemmatize(t),
            "numDigits=%s" % num_digits(t), 
            "containsDash=%s" % ('-' in t)
        ]
  
        features.append(tokenFeatures)
    
        if should_look_up:
            read_drug_list_files()
            (is_drug, isType) = use_db_resources(t)
            if is_drug: 
                tokenFeatures.append("Ruled = %s" %isType) 
            else: 
                tokenFeatures.append("Ruled = O") 
        
    for i, current_token in enumerate(features):
        # add previous token
        if i > 0:
            prev_token = features[i-1][0][5:]
            current_token.append("prev=%s" % prev_token)
            current_token.append("suf3Prev = %s" % prev_token[-3:])
            current_token.append("suf4Prev = %s" % prev_token[-4:])
            current_token.append("prevIsTitle = %s" % prev_token.istitle())
            current_token.append("prevIsUpper = %s" % prev_token.isupper())
            current_token.append("PrevIsDigit = %s" % prev_token.isdigit())

        else:
            current_token.append("prev=_BoS_") #beginning of sentence
            
        # add next token
        if i < len(features)-1:
            next_token = features[i+1][0][5:]
            current_token.append("next=%s" % next_token)
            current_token.append("suf3Next = %s" % next_token[-3:])
            current_token.append("suf4Next = %s" % next_token[-3:])
            current_token.append("NextIsTitle = %s" % next_token.istitle())
            current_token.append("NextIsUpper = %s" % next_token.isupper())
            current_token.append("NextIsDigit = %s" % next_token.isdigit())

        else:
            current_token.append("next=_EoS_") # end of sentence
            
    return features

# %%
tokenized_sent_2 = tokenize(sent_2)
feats_sent_2 = extract_features(tokenized_sent_2, should_look_up = True)
#print(feats_sent_2)

# %% [markdown]
# ### Feature Extractor function

# %%
def feature_extractor(datadir, resultpath, should_look_up = False):
    result_f = open(resultpath, 'w')
    # process each file in directory
    for f in listdir(datadir):

        # parse XML file, obtaining a DOM tree
        tree = parse(datadir + "/" + f)

        # process each sentence in the file
        sentences = tree.getElementsByTagName("sentence")
        for s in sentences:
            sid = s.attributes["id"].value # get sentence id
            stext = s.attributes["text"].value # get sentence text
            # load ground truth entities
            gold = []
            entities = s.getElementsByTagName("entity")
            for e in entities:
                # for discontinuous entities, we only get the first span
                offset = e.attributes["charOffset"].value      # e.g. 24-44
                try: # too many values to unpack in some iteration
                    (start, end) = offset.split(":")[0].split("-") # e.g. start:24, end:44
                except:
                    pass
                gold.append((int(start), int(end), e.attributes["type"].value)) # e.g. [(24, 44, 'drug')] 

            # tokenize text
            tokens = tokenize(stext)

            # extract features for each word in the sentence
            features = extract_features(tokens, should_look_up)

            # print features in format suitable for the learner/classifier
            for i in range (0, len(tokens)):
                # see if the token is part of an entity, and which part (B/I)
                tag = get_tag(tokens[i], gold)
                joined_features = "\t".join(features[i])
                result_f.write("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\n".format(sid, tokens[i][0], tokens[i][1], tokens[i][2], tag, joined_features))

# %%
train_dataset = '/Users/mponsclo/Downloads/labAHLT/data/train'
devel_dataset = '/Users/mponsclo/Downloads/labAHLT/data/devel'
test_dataset = '/Users/mponsclo/Downloads/labAHLT/data/test'

#feature_extractor(train_dataset, 'features_train')
#feature_extractor(devel_dataset, 'features_devel')
feature_extractor(test_dataset, 'features_test')

# %% [markdown]
# ### Learner: CRF

# %%
import pycrfsuite
from operator import itemgetter
from itertools import groupby

# %%
def parse_sentence_strings(sentence):
    '''
    Task:
        Given a stringified sentence, parse it and return the data in relevant data structures.
    Input:
        sentence: list of strings representing the given sentence, where each piece of information is separated by a tab, e.g.
            "DDI-DrugBank.d695.s0	While	0	4	O	form=While	formlower=while	suf3=ile	suf4=hile"
    Output:
        tokens: list of tuples representing tokens: (word, offset_from, offset_to)
        features: list of features for every token
        tags: list of tags (e.g. B-drug, O, I-brand etc.) for every token
    '''
    tags = []
    features = []
    tokens = []
    for token in sentence:
        split_data = token[:-1].split('\t')
        sentence_id = split_data[0]
        features.append(split_data[5:])
        tags.append(split_data[4])
        tokens.append((split_data[1], split_data[2], split_data[3]))
    return tokens, features, tags

def read_feature_file(filepath):
    '''
    Task:
        Given the path to the file containing tokenized sentences, read it and return the necessary data structures
    Input:
        filepath: Path to the data
    Output:
        tokens_by_sentence: list of tuples: (sentence_id, list_of_tokens). Each tuple represents a sentence,
            where in the list_of_tokens each token is represented by a tuple (word, offset_from, offset_to)
        features: list of lists of features per sentence
        tags: list of lists of B-I-O tags per sentence
    '''
    features = []
    tags = []
    tokens_by_sentence=[]
    
    f = open(filepath, 'r')
    lines = f.readlines()

    # group the tokens by sentence
    sentences = groupby(lines, lambda l: l.split('\t')[0])

    # process each sentence
    for sid, sentence in sentences:
        s_tokens, s_features, s_tags = parse_sentence_strings(sentence)
        
        tokens_by_sentence.append((sid, s_tokens))
        features.append(s_features)
        tags.append(s_tags)
           
    return tokens_by_sentence, features, tags

# %%
def crf_learn(features_file, model_name):
    
    # Read features from file
    _, X_train, y_train = read_feature_file(features_file)
    
    trainer = pycrfsuite.Trainer(verbose=False)
    for xseq, yseq in zip(X_train, y_train):
        trainer.append(xseq, yseq)
        
    trainer.set_params({
        'c1': 0.2, 
        'c2': 0.001,
        'max_iterations': 1000,
        'feature.possible_states': True,
        
        # include transitions that are possible, but not observed
        'feature.possible_transitions': True
    })
    
    trainer.train(model_name)
    return

# %%
crf_learn("features_train", "ml_model.crfsuite")

# %% [markdown]
# ### Classifier

# %%
def output_entities(sid, tokens, tags, outf):
    '''
    Task:
        Given a list of tokens and the B-I-O tag for each token, produce a list
            of drugs in the format expected by the evaluator.
    Input:
        sid: sentence identifier (required by the evaluator output format)
        tokens: List of tokens in the sentence , i.e. list of tuples (word,
            offsetFrom, offsetTo)
        tags: List of B-I-O tags for each token
    Output:
        Prints to stdout the entities in the right format: one line per entity,
        fields separated by ’|’, field order : id, offset, name, type.
    '''
    
    i = 0
    while i < len(tokens):
        entity, offset_from, offset_to = tokens[i]
        tag = tags[i]
        
        if tag[0] == 'B':
            tag_name = tag[2:]
            # in case the entity is longer than one word, concatenate it
            j = i + 1
            while j < len(tokens):
                word_next, offset_from_next, offset_to_next = tokens[j]
                tag_next = tags[j]
                j += 1
                if int(offset_from_next) - int(offset_to) != 2 or tag_next[0] != 'I':
                    break
                if tag_next[2:] == tag_name:
                    entity = entity + ' ' + word_next
                    offset_to = offset_to_next
            # print the whole entity
            outf.write(str(sid) + "|" + str(offset_from) + '-' + str(offset_to) + "|" + entity + "|" + tag_name)
            
            outf.write("\n")
            
        i += 1

# %%
def crf_classifier(model_name, features, inputdir, outputfile):
    
    outf = open(outputfile, "w")
        
    ids_and_tokens, X_devel, y_devel = read_feature_file(features)
    
    tagger = pycrfsuite.Tagger()
    tagger.open(model_name)
    tags = [tagger.tag(sentence) for sentence in X_devel]
    
    for sentence_tags, sentence_data in zip(tags, ids_and_tokens):
        sid, tokens = sentence_data
        output_entities(sid, tokens, sentence_tags, outf)
        
    outf.close()
    evaluate("NER", inputdir, outputfile)
    return

# %%
result = crf_classifier("ml_model.crfsuite", "features_test", test_dataset, "hello")
# Out:
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d526.s18|54-60|steroid|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d526.s24|5-12|estrogen|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d488.s0|38-44|Heparin|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d34.s11|67-70|iron|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d194.s1|92-100|etoposide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d194.s1|92-100|etoposide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d194.s1|92-100|etoposide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d751.s1|42-48|heparin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d751.s1|54-60|aspirin|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s4|129-139|zalcitabine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s6|78-87|lamivudine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s7|66-76|zalcitabine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s7|66-76|zalcitabine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s20|110-120|zalcitabine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s21|51-61|zalcitabine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d263.s25|0-10|Doxorubicin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d258.s1|59-68|loratadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d258.s1|59-68|loratadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d258.s4|40-51|erythromycin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d258.s7|59-68|Loratadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d495.s9|23-31|clonidine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d57.s1|13-26|aminoglycoside|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d634.s5|0-11|Theophylline|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d591.s0|74-84|anesthetics|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d591.s3|112-122|Ropivacaine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d591.s6|64-75|ketoconazole|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d591.s6|105-115|ropivacaine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s10|31-41|terfenadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s14|31-39|indinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s16|31-39|ritonavir|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s18|32-41|saquinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s18|32-41|saquinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d340.s30|31-39|rifabutin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d66.s2|50-61|indomethacin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d66.s7|112-121|paclitaxel|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d231.s10|54-63|furosemide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d231.s17|41-50|furosemide|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d61.s3|34-40|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d61.s9|21-27|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d710.s1|29-39|rimantadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d578.s4|111-128|methylprednisolone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d578.s8|29-38|salicylate|group
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d143.s3|19-28|omeprazole|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d404.s0|90-103|Cholestyramine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d404.s4|0-8|Thiazides|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d404.s8|0-11|Ketoconazole|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d115.s2|135-141|HIV-NHL|brand
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d115.s2|244-259|cyclophosphamide|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d115.s2|262-272|doxorubicin|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d115.s2|292-301|prednisone|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d115.s2|275-285|vincristine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d195.s4|26-33|warfarin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d195.s5|68-76|tamoxifen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d195.s8|21-31|anastrozole|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d195.s8|21-31|anastrozole|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d743.s2|84-94|terfenadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d743.s5|54-64|terfenadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d743.s5|134-145|itraconazole|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d743.s10|64-74|terfenadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d743.s12|30-40|terfenadine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d158.s2|0-18|Adrenergic blockers|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d158.s3|17-25|tricyclic|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d158.s4|0-12|d-amphetamine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d158.s12|0-13|Chlorpromazine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d158.s14|0-10|Haloperidol|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s7|46-55|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s8|6-15|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s10|36-45|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s15|73-82|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s17|69-78|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s20|238-249|cyclosporine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s22|59-65|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s23|36-42|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s30|36-44|quinidine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s31|36-47|procainamide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s31|36-47|procainamide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s36|15-24|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s37|24-33|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s48|51-60|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s50|6-15|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s50|6-15|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d143.s51|33-42|amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d412.s0|39-51|labetalol HCl|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d412.s7|81-89|halothane|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d599.s4|3-16|glucocorticoid|group
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d81.s2|71-77|ethanol|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d81.s3|58-64|ethanol|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d81.s6|47-53|ethanol|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d111.s14|15-27|acetaminophen|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d111.s14|48-60|phenobarbital|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d506.s5|42-50|quinidine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d506.s7|16-27|disopyramide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d506.s9|44-52|verapamil|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s0|28-39|flurbiprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s4|50-61|flurbiprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s12|110-121|flurbiprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s12|70-79|cimetidine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s18|109-117|glyburide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d529.s18|162-171|phenformin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d345.s5|75-85|propranolol|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d345.s6|109-119|propranolol|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d345.s16|14-37|colestipol hydrochloride|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d184.s5|55-65|amphetamine|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d184.s8|65-75|amphetamine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s1|101-104|AEDs|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s2|75-77|AED|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s11|20-27|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s15|21-29|phenytoin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s16|55-63|phenytoin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s16|91-98|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s17|63-75|carbamazepine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s18|59-71|carbamazepine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s21|39-51|carbamazepine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s23|41-49|valproate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s27|34-42|valproate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s28|50-62|phenobarbital|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s28|50-62|phenobarbital|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s28|50-62|phenobarbital|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s30|50-58|Phenytoin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s30|40-47|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s30|40-47|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s30|40-47|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s31|0-12|Carbamazepine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s31|84-91|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s31|84-91|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s32|73-81|valproate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s32|103-110|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s34|20-28|felbamate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s35|23-30|Felbatol|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d434.s37|146-158|contraceptive|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s6|90-99|ketoprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s6|72-78|aspirin|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s6|72-78|aspirin|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s13|71-80|ketoprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s13|86-92|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s17|64-73|ketoprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s19|0-9|Probenecid|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s19|53-62|ketoprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d499.s25|30-36|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d678.s4|43-55|acetaminophen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s10|22-32|epinephrine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s15|47-55|Clozapine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s18|42-54|carbamazepine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s18|28-36|Clozapine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s20|66-74|clozapine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s22|84-92|clozapine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d480.s29|19-27|clozapine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s4|0-32|Histamine H2-receptor antagonists|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s5|40-51|methotrexate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s8|92-104|ciprofloxacin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s12|86-95|Proquin XR|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s15|0-9|Probenecid|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s15|66-78|ciprofloxacin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d123.s16|93-104|theophylline|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d195.s4|112-120|ibuprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d195.s6|44-52|ibuprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d79.s1|29-37|indinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d79.s1|43-52|didanosine|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d79.s1|29-37|indinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d79.s2|12-20|indinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d79.s2|12-20|indinavir|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d703.s0|274-282|INCLUDING|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d487.s5|29-38|salicylate|group
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d201.s4|56-61|HB-EGF|brand
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d201.s8|0-5|HB-EGF|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d721.s0|50-56|calcium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d721.s0|23-28|SKELID|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d721.s0|23-28|SKELID|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d721.s1|40-45|SKELID|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d337.s3|37-64|HMG-CoA reductase inhibitors|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d337.s3|70-77|Fentanyl|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d558.s7|69-78|dofetilide|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d558.s12|21-24|HCTZ|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d558.s18|67-75|diuretics|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d172.s14|52-59|CELEBREX|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d172.s19|69-75|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d172.s19|69-75|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d172.s21|78-89|methotrexate|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d172.s22|66-73|warfarin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d665.s7|16-25|penicillin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d46.s7|21-30|colestipol|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d46.s7|32-37|resins|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d46.s16|46-52|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d485.s16|0-11|Atorvastatin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d485.s23|0-11|Griseofulvin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d485.s36|0-7|Rifampin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d485.s43|62-69|caffeine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d89.s3|36-43|caffeine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d89.s3|36-43|caffeine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d89.s3|36-43|caffeine|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d103.s1|36-44|magnesium|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d103.s1|36-44|magnesium|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d103.s1|36-44|magnesium|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d103.s3|94-102|magnesium|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d103.s5|19-27|magnesium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d415.s1|49-57|ibuprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d415.s8|102-110|ibuprofen|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d415.s12|51-57|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d415.s13|17-23|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d415.s15|25-31|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d29.s8|43-50|diazepam|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d450.s3|105-111|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d450.s7|28-34|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d450.s14|56-62|digoxin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d12.s8|59-66|fibrates|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d279.s11|94-102|CAMPTOSAR|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d11.s4|68-78|atomoxetine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s5|52-56|MOBIC|brand
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s19|73-79|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s20|56-62|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s20|56-62|lithium|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s27|55-62|warfarin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s28|43-50|warfarin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d597.s30|53-60|warfarin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d167.s2|66-76|anesthetics|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d603.s2|200-209|ProAmatine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d603.s5|0-9|ProAmatine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d411.s6|0-9|Amiodarone|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d411.s10|0-8|Cytokines|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d411.s18|0-11|Theophylline|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d700.s6|47-58|azathioprine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d700.s6|64-84|mycophenolate mofetil|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d330.s1|122-129|neomycin|drug
# Ignoring duplicated entity in system predictions file: DDI-MedLine.d14.s0|45-55|angiotensin|group
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s2|25-36|theophylline|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s3|25-36|cyclosporine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s4|11-22|cyclosporine|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s9|32-42|norfloxacin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s10|23-36|nitrofurantoin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s11|172-182|norfloxacin|drug
# Ignoring duplicated entity in system predictions file: DDI-DrugBank.d217.s12|178-188|norfloxacin|drug
#                    tp	  fp	  fn	#pred	#exp	P	R	F1
# ------------------------------------------------------------------------------
# brand             223	  55	  65	 278	 288	80.2%	77.4%	78.8%
# drug             1608	 137	 512	1745	2120	92.1%	75.8%	83.2%
# drug_n              2	   9	  70	  11	  72	18.2%	2.8%	4.8%
# group             517	 171	 182	 688	 699	75.1%	74.0%	74.5%
# ------------------------------------------------------------------------------
# M.avg            -	-	-	-	-	66.4%	57.5%	60.3%
# ------------------------------------------------------------------------------
# m.avg            2350	 372	 829	2722	3179	86.3%	73.9%	79.6%
# m.avg(no class)  2455	 266	 724	2721	3179	90.2%	77.2%	83.2%
