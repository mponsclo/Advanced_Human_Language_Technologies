# %% [markdown]
# Setup
# cd into ../stanford-corenlp-4.2.0 and run
#
# `java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer`

# %%
from os import listdir
from xml.dom.minidom import parse
# import nltk CoreNLP module (just once)
from nltk.parse.corenlp import CoreNLPDependencyParser
# connect to your CoreNLP server (just once)
corenlp_parser = CoreNLPDependencyParser(url="http://localhost:9000")

# %% [markdown]
# # DDI

# %%
def get_offsets(word, s):
    '''
    Task:
        Given a word and sentence, returns its starting end ending index in the sentence.
    
    Input:
        word: word to find offsets for
        s: sentence containing the word
    
    Output:
        Returns a tuple containing the start and end offset.
    '''
    start = s.find(word)
    end = start + len(word) - 1
    return start, end

# %%
def preprocess(s):
    '''
    Task:
        Helper function
    '''
    # because otherwise CoreNLP throws 500
    return s.replace("%", "<percentage>")

# %%
def analyze(s):
    '''
    Task:
        Given one sentence, sends it to CoreNLP to obtain the tokens, tags,
        and dependency tree. It also adds the start/end offsets to each token.
    
    Input:
        s: string containing the text for one sentence
    
    Output:
        Returns the nltk DependencyGraph object produced by CoreNLP, enriched with token  offsets.

    '''
    s = s.replace("%", "<percentage>")
    tree, = corenlp_parser.raw_parse(s)
    for n in tree.nodes.items():
        node = n[1]
        if node['word']:
            start, end = get_offsets(node['word'], s)
            node['start'] = start
            node['end'] = end
            
    return tree

# %%
def find_entity_in_tree(entity, tree):
    for n in tree.nodes.items():
        node = n[1]
        if node["word"] and (node["start"] == int(entity[0])) and (node["end"] == int(entity[1])):
            return node
    # PROBLEM: Ttwo-word entities?
    return None

# %%
def check_interaction(analysis, entities, e1, e2):
    '''
    Task:
        Decide whether a sentence is expressing a DDI between two drugs.
    
    Input:
        analysis: a DependencyGraph object with all sentence information
        entities: a list of all entities in the sentence (id and offsets)
        e1, e2: ids of the two entities to be checked
    
    Output:
        Returns the type of interaction ('effect', 'mechanism', 'advice', 'int') between e1 and e2
        expressed by the sentence, or 'None' if no interaction is described.
    '''
    tree = analysis.tree()
    
    entity1 = entities[e1]
    entity2 = entities[e2]
    
    e1_node = find_entity_in_tree(entity1, analysis)
    e2_node = find_entity_in_tree(entity2, analysis)
    
    e1_tag = e1_node['tag'] if e1_node else None
    e2_tag = e2_node['tag'] if e2_node else None
    
    h_e1 = e1_node['head'] if e1_node else None      #position of the head
    head_e1 = analysis.nodes[h_e1]['lemma'] if e1_node else None
    tag_head_e1 = analysis.nodes[h_e1]['tag'][0].lower() if e1_node else None
    
    h_e2 = e2_node['head'] if e2_node else None      #position of the head
    head_e2 = analysis.nodes[h_e2]['lemma'] if e2_node else None
    tag_head_e2 = analysis.nodes[h_e2]['tag'][0].lower() if e2_node else None
    
    if head_e1 == head_e2 and tag_head_e1 == 'v' and tag_head_e2 == 'v':
        under_same_verb = True
    else:
        under_same_verb = False
        
    if head_e1 == head_e2 and head_e1 != None and head_e2 != None:
        under_same_word = True
    else:
        under_same_word = False
    
    if head_e1 == entity2 and head_e1 != None:
        e1_under_e2 = True
    else: 
        e1_under_e2 = False
    
    if head_e2 == entity1 and head_e2 != None:
        e2_under_e1 = True
    else:
        e2_under_e1 = False
        
    # --- RULES ---
    if head_e1  == 'response' and head_e2 in ['man', 'alcohol', 'steroid']:
        return 'effect'
    if head_e1 == 'administer' and under_same_word:
        return 'advise'
    if head_e1 in ['response', 'effect', 'enhance']:
        return 'effect'
    if head_e1 in ['concentration', 'presence', 'dose', 'absorption', 'interfere']:
        return 'mechanism'
    if head_e1 in ['interact', 'interaction', 'action', 'agent']:
        return 'int'
    if head_e1 in ['co-administration', 'take', 'coadminister', 'treatment', 'therapy', 'tell']:
        return 'advise'
    if head_e2 in ['effect', 'alcohol', 'action', 'use', 'combination', 'inhibitor']:
        return 'effect'
    if head_e2 in ['metabolism', 'concentration', 'clearance', 'level', 'absorption', 'dose']:
        return 'mechanism'
    if head_e2 in ['interact', 'interaction']:
        return 'int'
    if under_same_word:
        return 'mechanism' # or "int"
    if e1_under_e2:
        return 'effect'
    

    return None

# %%
datadir = "../../labAHLT/data/devel"

# process each file in directory
for f in listdir (datadir):
    # parse XML file , obtaining a DOM tree
    tree = parse ( datadir + "/" + f)
    # process each sentence in the file
    sentences = tree.getElementsByTagName("sentence")
    for s in sentences:

        sid = s.attributes ["id"].value # get sentence id
        stext = s.attributes ["text"].value # get sentence text
        
        # CoreNLP throws error for empty sentences
        if len(stext) == 0:
            continue

        # load sentence entities into a dictionary
        entities = {}
        ents = s.getElementsByTagName("entity")
        for e in ents:
            eid = e . attributes ["id"].value
            entities[eid] = e.attributes["charOffset"].value.split("-")

        # Tokenize, tag, and parse sentence
        analysis = analyze(stext)

        # for each pair in the sentence , decide whether it is DDI and its type
        pairs = s.getElementsByTagName("pair")
        for p in pairs:
            id_e1 = p.attributes["e1"].value
            id_e2 = p.attributes["e2"].value
            ddi_type = check_interaction(analysis, entities , id_e1 , id_e2 )
            if ddi_type != None :
                print (sid +"|"+ id_e1 +"|"+ id_e2 +"|"+ ddi_type)
# Out:
# DDI-DrugBank.d105.s0|DDI-DrugBank.d105.s0.e3|DDI-DrugBank.d105.s0.e4|mechanism
# DDI-DrugBank.d153.s4|DDI-DrugBank.d153.s4.e0|DDI-DrugBank.d153.s4.e2|effect
# DDI-DrugBank.d153.s4|DDI-DrugBank.d153.s4.e1|DDI-DrugBank.d153.s4.e2|effect
# DDI-DrugBank.d654.s0|DDI-DrugBank.d654.s0.e0|DDI-DrugBank.d654.s0.e1|advise
# DDI-DrugBank.d654.s0|DDI-DrugBank.d654.s0.e0|DDI-DrugBank.d654.s0.e2|advise
# DDI-DrugBank.d654.s1|DDI-DrugBank.d654.s1.e0|DDI-DrugBank.d654.s1.e2|effect
# DDI-DrugBank.d654.s1|DDI-DrugBank.d654.s1.e1|DDI-DrugBank.d654.s1.e2|effect
# DDI-DrugBank.d654.s2|DDI-DrugBank.d654.s2.e0|DDI-DrugBank.d654.s2.e1|mechanism
# DDI-MedLine.d23.s0|DDI-MedLine.d23.s0.e0|DDI-MedLine.d23.s0.e1|effect
# DDI-MedLine.d23.s0|DDI-MedLine.d23.s0.e0|DDI-MedLine.d23.s0.e2|effect
# DDI-MedLine.d23.s2|DDI-MedLine.d23.s2.e1|DDI-MedLine.d23.s2.e4|mechanism
# DDI-MedLine.d23.s2|DDI-MedLine.d23.s2.e1|DDI-MedLine.d23.s2.e5|mechanism
# DDI-MedLine.d23.s2|DDI-MedLine.d23.s2.e2|DDI-MedLine.d23.s2.e3|mechanism
# DDI-DrugBank.d97.s52|DDI-DrugBank.d97.s52.e0|DDI-DrugBank.d97.s52.e1|effect
# DDI-DrugBank.d97.s57|DDI-DrugBank.d97.s57.e2|DDI-DrugBank.d97.s57.e3|mechanism
# DDI-DrugBank.d97.s60|DDI-DrugBank.d97.s60.e2|DDI-DrugBank.d97.s60.e3|mechanism
# DDI-DrugBank.d97.s63|DDI-DrugBank.d97.s63.e0|DDI-DrugBank.d97.s63.e1|mechanism
# DDI-DrugBank.d97.s64|DDI-DrugBank.d97.s64.e1|DDI-DrugBank.d97.s64.e2|mechanism
# DDI-DrugBank.d97.s64|DDI-DrugBank.d97.s64.e3|DDI-DrugBank.d97.s64.e4|mechanism
# DDI-DrugBank.d97.s68|DDI-DrugBank.d97.s68.e0|DDI-DrugBank.d97.s68.e1|mechanism
# DDI-DrugBank.d97.s70|DDI-DrugBank.d97.s70.e0|DDI-DrugBank.d97.s70.e1|effect
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e0|DDI-DrugBank.d97.s72.e1|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e0|DDI-DrugBank.d97.s72.e2|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e0|DDI-DrugBank.d97.s72.e3|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e0|DDI-DrugBank.d97.s72.e4|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e0|DDI-DrugBank.d97.s72.e5|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e1|DDI-DrugBank.d97.s72.e5|effect
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e2|DDI-DrugBank.d97.s72.e5|effect
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e3|DDI-DrugBank.d97.s72.e4|mechanism
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e3|DDI-DrugBank.d97.s72.e5|effect
# DDI-DrugBank.d97.s72|DDI-DrugBank.d97.s72.e4|DDI-DrugBank.d97.s72.e5|effect
# DDI-DrugBank.d97.s73|DDI-DrugBank.d97.s73.e2|DDI-DrugBank.d97.s73.e3|mechanism
# DDI-DrugBank.d97.s83|DDI-DrugBank.d97.s83.e0|DDI-DrugBank.d97.s83.e1|mechanism
# DDI-DrugBank.d97.s87|DDI-DrugBank.d97.s87.e0|DDI-DrugBank.d97.s87.e1|mechanism
# DDI-DrugBank.d97.s90|DDI-DrugBank.d97.s90.e0|DDI-DrugBank.d97.s90.e1|mechanism
# DDI-DrugBank.d97.s93|DDI-DrugBank.d97.s93.e0|DDI-DrugBank.d97.s93.e1|mechanism
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-93c124923889> in <module>
#      31             id_e1 = p.attributes["e1"].value
#      32             id_e2 = p.attributes["e2"].value
# ---> 33             ddi_type = check_interaction(analysis, entities , id_e1 , id_e2 )
#      34             if ddi_type != None :
#      35                 print (sid +"|"+ id_e1 +"|"+ id_e2 +"|"+ ddi_type)
#
# <ipython-input-33-4a52c1beff61> in check_interaction(analysis, entities, e1, e2)
#      19
#      20     e1_node = find_entity_in_tree(entity1, analysis)
# ---> 21     e2_node = find_entity_in_tree(entity2, analysis)
#      22
#      23     e1_tag = e1_node['tag'] if e1_node else None
#
# <ipython-input-32-c1c15b907593> in find_entity_in_tree(entity, tree)
#       2     for n in tree.nodes.items():
#       3         node = n[1]
# ----> 4         if node["word"] and (node["start"] == int(entity[0])) and (node["end"] == int(entity[1])):
#       5             return node
#       6     # PROBLEM: Ttwo-word entities?
#
# ValueError: invalid literal for int() with base 10: '65;75'

# %%
#StanfordCoreNLP throws error 500 when a sentence contains '%':
#    Illegal hex characters in escape (%) pattern - Error at index 0 in: " a"
#  java.base/java.net.URLDecoder.decode(URLDecoder.java:232)
#  java.base/java.net.URLDecoder.decode(URLDecoder.java:142)
